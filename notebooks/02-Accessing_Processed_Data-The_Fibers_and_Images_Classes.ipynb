# %% [markdown]
# # 02 - Accessing Processed Data: The Fibers and Images Classes

# %% [markdown]
# All data for a single HETDEX observation (a dither set of three exposures), is stored in one HDF5 file. This file contains the processed data in the form of 2D image data and individual fiber data. It also contains branches including information about the astrometric and flux-calibration details. Most users will be most interested in the flux-calibrated fiber information and 2D image data. A user can access all fibers observated at a specific RA/DEC and perform analysis on these retrieved fibers. This data can be retrieved through the Fibers class. The 2D image data represents the intermediary processed data. It provides images for each IFU/amp (essential the original CCD image of the fiber spectra) along each step of calibration. Please refer to Panacea documentation for detailed information on the reduciton process.
#
# We begin by first introducing some global shot functions and then delve into the Fibers and Images classes.

# %% [markdown]
# ## Global Functions of the Shot API

# %% [markdown]
# If you want to just open the shot HDF5 file and explore contents, you must know the shot ID: either its interger shotid value (20180124010) or the datevobs ('20180124v010'). The last notebook showed how to find a list of shots based on querying the Survey Class. An HDF5 file can be opened using the `get_shot_file()` global command:

# %%
# %run ../shot.py

# %%
fileh = open_shot_file('20180124v010')

# %% [markdown]
# To see all contents of the shot file:

# %%
print(fileh)
# Out:
# /users/erin/Desktop/20180124v010.h5 (File) ''
# Last modif.: 'Wed Feb 20 13:16:53 2019'
# Object Tree:
# / (RootGroup) ''
# /Shot (Table(1,)) 'Shot Info'
# /Astrometry (Group) 'Astrometry Info'
# /Astrometry/QA (Table(3,)) 'Qulity Assessment'
# /Astrometry/StarCatalog (Table(33,)) ''
# /Astrometry/fplane (Table(31,)) ''
# /Calibration (Group) 'HETDEX Calibration Info'
# /Data (Group) 'VIRUS Fiber Data and Metadata'
# /Data/Fibers (Table(29568,)) 'Fiber Info'
# /Data/Images (Table(264,)) 'Image Info'
# /Calibration/AmpToAmp (Group) 'Amp to amp Fiber Normalization'
# /Calibration/AmpToAmp/multi_008_093_054_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_008_093_054_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_008_093_054_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_008_093_054_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_012_106_033_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_012_106_033_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_012_106_033_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_012_106_033_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_013_103_019_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_013_103_019_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_013_103_019_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_013_103_019_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_016_104_026_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_016_104_026_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_016_104_026_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_016_104_026_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_017_086_022_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_017_086_022_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_017_086_022_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_017_086_022_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_020_095_004_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_020_095_004_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_020_095_004_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_020_095_004_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_024_083_023_LL (Table(40,)) ''
# /Calibration/AmpToAmp/multi_024_083_023_LU (Table(40,)) ''
# /Calibration/AmpToAmp/multi_024_083_023_RL (Table(40,)) ''
# /Calibration/AmpToAmp/multi_024_083_023_RU (Table(40,)) ''
# /Calibration/AmpToAmp/multi_025_076_032_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_025_076_032_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_025_076_032_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_025_076_032_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_027_085_001_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_027_085_001_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_027_085_001_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_027_085_001_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_032_094_028_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_032_094_028_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_032_094_028_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_032_094_028_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_037_073_031_LL (Table(40,)) ''
# /Calibration/AmpToAmp/multi_037_073_031_LU (Table(40,)) ''
# /Calibration/AmpToAmp/multi_037_073_031_RL (Table(40,)) ''
# /Calibration/AmpToAmp/multi_037_073_031_RU (Table(40,)) ''
# /Calibration/AmpToAmp/multi_038_096_014_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_038_096_014_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_038_096_014_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_038_096_014_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_041_084_015_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_041_084_015_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_041_084_015_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_041_084_015_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_047_075_075_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_047_075_075_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_047_075_075_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_047_075_075_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_051_105_051_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_051_105_051_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_051_105_051_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_051_105_051_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_202_035_074_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_202_035_074_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_202_035_074_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_202_035_074_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_202_044_074_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_202_044_074_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_202_044_074_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_202_044_074_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_203_073_031_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_203_073_031_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_203_073_031_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_203_073_031_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_204_077_037_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_204_077_037_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_204_077_037_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_204_077_037_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_205_067_058_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_205_067_058_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_205_067_058_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_205_067_058_RU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_301_015_038_LL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_301_015_038_LU (Table(100,)) ''
# /Calibration/AmpToAmp/multi_301_015_038_RL (Table(100,)) ''
# /Calibration/AmpToAmp/multi_301
# /Astrometry/CoaddImages/exp02 (ImageArray(1300, 1300)) ''
# /Astrometry/CoaddImages/exp03 (ImageArray(1300, 1300)) ''
# /Astrometry/CoaddImages/png_exp01 (ImageArray(800, 800, 4)) ''
# /Astrometry/CoaddImages/png_exp02 (ImageArray(800, 800, 4)) ''
# /Astrometry/CoaddImages/png_exp03 (ImageArray(800, 800, 4)) ''
# /Astrometry/Dithall (Group) 'Fiber Astrometry Info'
# /Astrometry/Dithall/exp01 (Table(9856,)) ''
# /Astrometry/Dithall/exp02 (Table(9856,)) ''
# /Astrometry/Dithall/exp03 (Table(9856,)) ''
# /Astrometry/PositionOffsets (Group) 'Offset in star matches'
# /Astrometry/PositionOffsets/exp01 (Table(18,)) ''
# /Astrometry/PositionOffsets/exp02 (Table(20,)) ''
# /Astrometry/PositionOffsets/exp03 (Table(21,)) ''

# %% [markdown]
# ## Initiate the Fibers Class

# %% [markdown]
# To access the fibers of a given shot, you can open the HDF5 container load in the RA/DEC of each fiber as an astropy coordinates object in one instance:

# %%
fibers = Fibers('20180124v010')

# %% [markdown]
# The HDF5 container file is stored as an attribute to the Fibers class:

# %%
fibers.hdfile
# Out:
# File(filename=/users/erin/Desktop/20180124v010.h5, title='', mode='r', root_uep='/', filters=Filters(complevel=0, shuffle=False, bitshuffle=False, fletcher32=False, least_significant_digit=None))
# / (RootGroup) ''
# /Shot (Table(1,)) 'Shot Info'
#   description := {
#   "date": Int32Col(shape=(), dflt=0, pos=0),
#   "obsid": Int32Col(shape=(), dflt=0, pos=1),
#   "ra": Float32Col(shape=(), dflt=0.0, pos=2),
#   "dec": Float32Col(shape=(), dflt=0.0, pos=3),
#   "objid": StringCol(itemsize=18, shape=(), dflt='', pos=4),
#   "pa": Float32Col(shape=(), dflt=0.0, pos=5),
#   "mjd": Float32Col(shape=(), dflt=0.0, pos=6),
#   "ambtemp": Float32Col(shape=(), dflt=0.0, pos=7),
#   "dewpoint": Float32Col(shape=(), dflt=0.0, pos=8),
#   "expn": Int32Col(shape=(), dflt=0, pos=9),
#   "exptime": Float32Col(shape=(), dflt=0.0, pos=10),
#   "humidity": Float32Col(shape=(), dflt=0.0, pos=11),
#   "obsind": Int32Col(shape=(), dflt=0, pos=12),
#   "pressure": Float32Col(shape=(), dflt=0.0, pos=13),
#   "time": StringCol(itemsize=7, shape=(), dflt='', pos=14)}
#   byteorder := 'little'
#   chunkshape := (851,)
# /Astrometry (Group) 'Astrometry Info'
# /Astrometry/QA (Table(3,)) 'Qulity Assessment'
#   description := {
#   "expnum": Int32Col(shape=(), dflt=0, pos=0),
#   "xoffset": Float32Col(shape=(), dflt=0.0, pos=1),
#   "yoffset": Float32Col(shape=(), dflt=0.0, pos=2),
#   "xrms": Float32Col(shape=(), dflt=0.0, pos=3),
#   "yrms": Float32Col(shape=(), dflt=0.0, pos=4),
#   "nstars": Float32Col(shape=(), dflt=0.0, pos=5)}
#   byteorder := 'little'
#   chunkshape := (2730,)
# /Astrometry/StarCatalog (Table(33,)) ''
#   description := {
#   "ignore": Int64Col(shape=(), dflt=0, pos=0),
#   "star_ID": Int64Col(shape=(), dflt=0, pos=1),
#   "ra_cat": Float64Col(shape=(), dflt=0.0, pos=2),
#   "dec_cat": Float64Col(shape=(), dflt=0.0, pos=3),
#   "u": Float64Col(shape=(), dflt=0.0, pos=4),
#   "g": Float64Col(shape=(), dflt=0.0, pos=5),
#   "r": Float64Col(shape=(), dflt=0.0, pos=6),
#   "i": Float64Col(shape=(), dflt=0.0, pos=7),
#   "z": Float64Col(shape=(), dflt=0.0, pos=8)}
#   byteorder := 'little'
#   chunkshape := (910,)
# /Astrometry/fplane (Table(31,)) ''
#   description := {
#   "ifuslot": Int64Col(shape=(), dflt=0, pos=0),
#   "fpx": Float64Col(shape=(), dflt=0.0, pos=1),
#   "fpy": Float64Col(shape=(), dflt=0.0, pos=2),
#   "specid": Int64Col(shape=(), dflt=0, pos=3),
#   "specslot": Int64Col(shape=(), dflt=0, pos=4),
#   "ifuid": Int64Col(shape=(), dflt=0, pos=5),
#   "ifurot": Float64Col(shape=(), dflt=0.0, pos=6),
#   "platesc": Float64Col(shape=(), dflt=0.0, pos=7)}
#   byteorder := 'little'
#   chunkshape := (1024,)
# /Calibration (Group) 'HETDEX Calibration Info'
# /Data (Group) 'VIRUS Fiber Data and Metadata'
# /Data/Fibers (Table(29568,)) 'Fiber Info'
#   description := {
#   "multiframe": StringCol(itemsize=20, shape=(), dflt='', pos=0),
#   "ra": Float32Col(shape=(), dflt=0.0, pos=1),
#   "dec": Float32Col(shape=(), dflt=0.0, pos=2),
#   "Amp2Amp": Float32Col(shape=(1036,), dflt=0.0, pos=3),
#   "Throughput": Float32Col(shape=(1036,), dflt=0.0, pos=4),
#   "amp": StringCol(itemsize=2, shape=(), dflt='', pos=5),
#   "calfib": Float32Col(shape=(1036,), dflt=0.0, pos=6),
#   "calfibe": Float32Col(shape=(1036,), dflt=0.0, pos=7),
#   "contid": StringCol(itemsize=8, shape=(), dflt='', pos=8),
#   "error1Dfib": Float32Col(shape=(1032,), dflt=0.0, pos=9),
#   "expnum": Int32Col(shape=(), dflt=0, pos=10),
#   "fiber_to_fiber": Float32Col(shape=(1032,), dflt=0.0, pos=11),
#   "fibnum": Int32Col(shape=(), dflt=0, pos=12),
#   "fpx": Float32Col(shape=(), dflt=0.0, pos=13),
#   "fpy": Float32Col(shape=(), dflt=0.0, pos=14),
#   "ifuid": StringCol(itemsize=3, shape=(), dflt='', pos=15),
#   "ifuslot": StringCol(itemsize=3, shape=(), dflt='', pos=16),
#   "ifux": Float32Col(shape=(), dflt=0.0, pos=17),
#   "ifuy": Float32Col(shape=(), dflt=0.0, pos=18),
#   "obsind": Int32Col(shape=(), dflt=0, pos=19),
#   "sky_subtracted": Float32Col(shape=(1032,), dflt=0.0, pos=20),
#   "specid": StringCol(itemsize=3, shape=(), dflt='', pos=21),
#   "spectrum": Float32Col(shape=(1032,), dflt=0.0, pos=22),
#   "trace": Float32Col(shape=(1032,), dflt=0.0, pos=23),
#   "twi_spectrum": Float32Col(shape=(1032,), dflt=0.0, pos=24),
#   "wavelength": Float32Col(shape=(1032,), dflt=0.0, pos=25)}
#   byteorder := 'little'
#   chunkshape := (5,)
#   autoindex := True
#   colindexes := {
#     "multiframe": Index(9, full, shuffle, zlib(1)).is_csi=True}
# /Data/Images (Table(264,)) 'Image Info'
)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_309_046_005_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_309_046_005_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_309_046_005_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_309_046_005_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_310_033_002_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_310_033_002_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_310_033_002_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_310_033_002_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_311_036_053_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_311_036_053_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_311_036_053_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_311_036_053_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_311_053_025_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_311_053_025_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_311_053_025_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_311_053_025_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_312_045_065_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_312_045_065_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_312_045_065_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_312_045_065_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_312_047_065_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_312_047_065_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_312_047_065_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_312_047_065_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_313_023_010_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_313_023_010_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_313_023_010_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_313_023_010_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_313_037_010_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_313_037_010_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_313_037_010_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_313_037_010_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_314_027_011_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_314_027_011_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_314_027_011_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_314_027_011_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_315_021_073_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_315_021_073_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_315_021_073_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_315_021_073_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_315_042_073_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_315_042_073_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_315_042_073_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_315_042_073_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_316_022_052_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_316_022_052_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_316_022_052_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_316_022_052_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_316_032_052_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_316_032_052_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# ...
# /Calibration/AmpToAmp/multi_320_053_020_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_321_026_035_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_321_026_035_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_321_026_035_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_321_026_035_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_321_042_030_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_321_042_030_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_321_042_030_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_321_042_030_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_322_063_062_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_322_063_062_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_322_063_062_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_322_063_062_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_323_043_040_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_323_043_040_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_323_043_040_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_323_043_040_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_323_052_016_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_323_052_016_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_323_052_016_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_323_052_016_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_324_062_055_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_324_062_055_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_324_062_055_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_324_062_055_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_325_072_044_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_325_072_044_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_325_072_044_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_325_072_044_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_326_082_034_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_326_082_034_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_326_082_034_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_326_082_034_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_327_092_017_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_327_092_017_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_327_092_017_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_327_092_017_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_328_087_048_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_328_087_048_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_328_087_048_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_328_087_048_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_329_097_029_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_329_097_029_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_329_097_029_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_329_097_029_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_401_013_043_LL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_401_013_043_LU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_401_013_043_RL (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/AmpToAmp/multi_401_013_043_RU (Table(100,)) ''
#   description := {
#   "wave": Float64Col(shape=(), dflt=0.0, pos=0),
#   "norm": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
# /Calibration/Throughput (Group) 'Throughput Curves'
# /Calibration/Throughput/throughput (Table(21,)) ''
#   description := {
#   "col1": Float64Col(shape=(), dflt=0.0, pos=0),
#   "col2": Float64Col(shape=(), dflt=0.0, pos=1),
#   "col3": Float64Col(shape=(), dflt=0.0, pos=2)}
#   byteorder := 'little'
#   chunkshape := (2730,)
# /Astrometry/CoaddImages (Group) 'Coadd Images'
# /Astrometry/CoaddImages/exp01 (ImageArray(1300, 1300)) ''
#   atom := Float32Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'big'
#   chunkshape := None
# /Astrometry/CoaddImages/exp02 (ImageArray(1300, 1300)) ''
#   atom := Float32Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'big'
#   chunkshape := None
# /Astrometry/CoaddImages/exp03 (ImageArray(1300, 1300)) ''
#   atom := Float32Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'big'
#   chunkshape := None
# /Astrometry/CoaddImages/png_exp01 (ImageArray(800, 800, 4)) ''
#   atom := Float32Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := None
# /Astrometry/CoaddImages/png_exp02 (ImageArray(800, 800, 4)) ''
#   atom := Float32Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := None
# /Astrometry/CoaddImages/png_exp03 (ImageArray(800, 800, 4)) ''
#   atom := Float32Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := None
# /Astrometry/Dithall (Group) 'Fiber Astrometry Info'
# /Astrometry/Dithall/exp01 (Table(9856,)) ''
#   description := {
#   "ra": Float64Col(shape=(), dflt=0.0, pos=0),
#   "dec": Float64Col(shape=(), dflt=0.0, pos=1),
#   "ifuslot": StringCol(itemsize=6, shape=(), dflt='', pos=2),
#   "XS": Float64Col(shape=(), dflt=0.0, pos=3),
#   "YS": Float64Col(shape=(), dflt=0.0, pos=4),
#   "dxfplane": Float64Col(shape=(), dflt=0.0, pos=5),
#   "yfplane": Float64Col(shape=(), dflt=0.0, pos=6),
#   "multifits": StringCol(itemsize=28, shape=(), dflt='', pos=7),
#   "timestamp": StringCol(itemsize=17, shape=(), dflt='', pos=8),
#   "exposure": StringCol(itemsize=5, shape=(), dflt='', pos=9)}
#   byteorder := 'little'
#   chunkshape := (630,)
# /Astrometry/Dithall/exp02 (Table(9856,)) ''
#   description := {
#   "ra": Float64Col(shape=(), dflt=0.0, pos=0),
#   "dec": Float64Col(shape=(), dflt=0.0, pos=1),
#   "ifuslot": StringCol(itemsize=6, shape=(), dflt='', pos=2),
#   "XS": Float64Col(shape=(), dflt=0.0, pos=3),
#   "YS": Float64Col(shape=(), dflt=0.0, pos=4),
#   "dxfplane": Float64Col(shape=(), dflt=0.0, pos=5),
#   "yfplane": Float64Col(shape=(), dflt=0.0, pos=6),
#   "multifits": StringCol(itemsize=28, shape=(), dflt='', pos=7),
#   "timestamp": StringCol(itemsize=17, shape=(), dflt='', pos=8),
#   "exposure": StringCol(itemsize=5, shape=(), dflt='', pos=9)}
#   byteorder := 'little'
#   chunkshape := (630,)
# /Astrometry/Dithall/exp03 (Table(9856,)) ''
#   description := {
#   "ra": Float64Col(shape=(), dflt=0.0, pos=0),
#   "dec": Float64Col(shape=(), dflt=0.0, pos=1),
#   "ifuslot": StringCol(itemsize=6, shape=(), dflt='', pos=2),
#   "XS": Float64Col(shape=(), dflt=0.0, pos=3),
#   "YS": Float64Col(shape=(), dflt=0.0, pos=4),
#   "dxfplane": Float64Col(shape=(), dflt=0.0, pos=5),
#   "yfplane": Float64Col(shape=(), dflt=0.0, pos=6),
#   "multifits": StringCol(itemsize=28, shape=(), dflt='', pos=7),
#   "timestamp": StringCol(itemsize=17, shape=(), dflt='', pos=8),
#   "exposure": StringCol(itemsize=5, shape=(), dflt='', pos=9)}
#   byteorder := 'little'
#   chunkshape := (630,)
# /Astrometry/PositionOffsets (Group) 'Offset in star matches'
# /Astrometry/PositionOffsets/exp01 (Table(18,)) ''
#   description := {
#   "xoffset": Float64Col(shape=(), dflt=0.0, pos=0),
#   "yoffset": Float64Col(shape=(), dflt=0.0, pos=1),
#   "ra_dex": Float64Col(shape=(), dflt=0.0, pos=2),
#   "dec_dex": Float64Col(shape=(), dflt=0.0, pos=3),
#   "ra_cat": Float64Col(shape=(), dflt=0.0, pos=4),
#   "dec_cat": Float64Col(shape=(), dflt=0.0, pos=5),
#   "ifuslot": Int64Col(shape=(), dflt=0, pos=6)}
#   byteorder := 'little'
#   chunkshape := (1170,)
# /Astrometry/PositionOffsets/exp02 (Table(20,)) ''
#   description := {
#   "xoffset": Float64Col(shape=(), dflt=0.0, pos=0),
#   "yoffset": Float64Col(shape=(), dflt=0.0, pos=1),
#   "ra_dex": Float64Col(shape=(), dflt=0.0, pos=2),
#   "dec_dex": Float64Col(shape=(), dflt=0.0, pos=3),
#   "ra_cat": Float64Col(shape=(), dflt=0.0, pos=4),
#   "dec_cat": Float64Col(shape=(), dflt=0.0, pos=5),
#   "ifuslot": Int64Col(shape=(), dflt=0, pos=6)}
#   byteorder := 'little'
#   chunkshape := (1170,)
# /Astrometry/PositionOffsets/exp03 (Table(21,)) ''
#   description := {
#   "xoffset": Float64Col(shape=(), dflt=0.0, pos=0),
#   "yoffset": Float64Col(shape=(), dflt=0.0, pos=1),
#   "ra_dex": Float64Col(shape=(), dflt=0.0, pos=2),
#   "dec_dex": Float64Col(shape=(), dflt=0.0, pos=3),
#   "ra_cat": Float64Col(shape=(), dflt=0.0, pos=4),
#   "dec_cat": Float64Col(shape=(), dflt=0.0, pos=5),
#   "ifuslot": Int64Col(shape=(), dflt=0, pos=6)}
#   byteorder := 'little'
#   chunkshape := (1170,)

# %% [markdown]
# The following are functions that act upon the fibers class to aid in querying and retrieving fibers. Use `query_region_idx()` to get the index of all fibers within a defined circular aperture. The center of the aperture must be an astropy coords object, for example:

# %%
idx = fibers.query_region_idx(coords, radius=3*u.arcsec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-e46a3171787e> in <module>()
# ----> 1 idx = fibers.query_region_idx(coords, radius=3*u.arcsec)
#
# NameError: name 'coords' is not defined
